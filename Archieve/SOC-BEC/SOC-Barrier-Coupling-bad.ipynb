# %%
import math
import numpy as np
from mmfutils.performance.fft import fftn, ifftn
from mmfutils.performance.fft import fftn, ifftn

from pytimeode import interfaces, mixins, evolvers
import CoupledState2
reload(CoupledState2)
from CoupledState2 import State2, u

# %%
# %pylab inline --no-import-all
from IPython.display import display, clear_output
s = State2(Nxyz=(128,), Lxyz=(40*u.micron,),ws = np.array([26.0, ])*u.Hz, N=1e5)
s.plot()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
def get_err(N=128, L=24*u.micron):
    s = State2(Nxyz=(N,), Lxyz=(L,), N=1e5)
    s.g11=s.g22=s.g12 = s.RabiFrequency = 0
    a = np.sqrt(u.hbar/u.m/s.ws[0])
    x = s.xyz[0]
    psi_0 = np.exp(-(x/a)**2/2.0)
    s[...] = psi_0
    s.normalize()
    dy = s.empty()
    s.compute_dy_dt(dy=dy, subtract_mu=True)
    return abs(dy[...]).max()
Ns = np.arange(2,128,2)
errs = map(get_err, Ns)
plt.semilogy(Ns, errs, '+-')

# %%
s = State2(Nxyz=(46,), Lxyz=(23*u.micron,))
a = np.sqrt(u.hbar/u.m/s.ws[0])
L, N = s.Lxyz[0], s.Nxyz[0]
k_max = np.pi*(N-2)/L   # For Khalid...
print (k_max, s.kxyz[0].max())
print(np.exp(-(L/2/a)**2/2))   # Wavefunction drops by factor of macheps
# Out:
# (6.010003337302212, 6.010003337302213)
# 9.87009441159e-15

# %%
psi_0 = s.xyz[0]*np.exp(-(s.xyz[0]/a)**2/2)
plt.semilogy(np.fft.fftshift(s.kxyz[0]), 
         np.fft.fftshift(abs(np.fft.fft(psi_0))), '-+')

# %%
# %pylab inline --no-import-all
from IPython.display import display, clear_output
import States
from States import State, u
s = State(Nxyz=(64,), Lxyz=(23*u.micron,), N=1e5)
a = np.sqrt(u.hbar/u.m/s.ws[0])
x = s.xyz[0]
psi_0 = np.exp(-(x/a)**2/2)
#print(x)
#print(psi_0)
class State1(State2):
    def __init__(self, *v, **kw):
        State.__init__(self, *v, **kw)
        a = np.sqrt(u.hbar/u.m/self.ws[0])
        x = self.xyz[0]
        k = 1./2./a**2
        psi_0 = 4.0*np.exp(-(x/a)**2/2)
        n_0 = abs(psi_0)**2
        self._V_ext = (u.hbar**2/2.0/u.m*(4*(k*x)**2 - 2*k) - self.g*n_0)
        self.data[...] = psi_0
        self.get_Vext = lambda: self._V_ext
        self.pre_evolve_hook()
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
s = State2(Nxyz=(64,), Lxyz=(23*u.micron,))
s.plot()
plt.plot(x, s.get_Vext())
dy = s.empty()
s.compute_dy_dt(dy=dy, subtract_mu=False)
abs(dy[...]).max()
# Out:
# 1.2867553465376567

# %%
#print(s.kxyz)
K1=sum((u.hbar*_k)**2/2.0/u.m for _k in s.kxyz)
#print(K1)
K=(u.hbar*s.kxyz[0])**2/u.m
#print(K)

# %%
from mmfutils.contexts import NoInterrupt
from pytimeode.evolvers import EvolverSplit, EvolverABM
from IPython.display import display, clear_output

s = State2(Nxyz=(64*4,), Lxyz=(23*u.micron,))
assert np.allclose(s._N, s.get_N())
s[0] = 1.0
s[1] = 1.0
s.normalize()
s.cooling_phase = 1j
E_max = u.hbar**2*np.abs(s.kxyz).max()**2/2.0/u.m
e = EvolverABM(s, dt=0.1*u.hbar/E_max, normalize=True)
e.y.plot()

# %%
e.y.t=0
e.y.RabiFrequency = 0

e.y.cooling_phase = 1j
e.y.barrierFlag = False
e.y.g22 = 4 * np.pi * u.hbar**2 * u.a/u.m
with NoInterrupt(ignore=True) as interrupted:
    while e.y.t < 1*u.ms and not interrupted:
        e.evolve(100)
        plt.clf()
        e.y.plot()
        display(plt.gcf())
        clear_output(wait=True)

# %%
b=s.get_Barrier(20)
s.barrierFlag=False
plt.plot(s.xyz[0],s.get_V()[0])

# %%
e.y.cooling_phase = 1
e.y.barrierFlag = True
e.y.t = 0;
e.y.g22 = 0.75 * e.y.g11
e.y.g12 = 0
e.y.barrierOffset = -3.5
e.y.barrierIensity = 10.0
e.y.barrierWidth = np.array([0.3,])
e.y.barrierVelocity = np.array([.175,])
with NoInterrupt(ignore=True) as interrupted:
    while e.y.t < 2*u.ms and not interrupted:
        e.evolve(100)
        plt.clf()
        e.y.plot()
        plt.plot(e.y.xyz[0],e.y.get_V()[0])
        display(plt.gcf())
        clear_output(wait=True)

# %%
e.y.RabiFrequency = 1000
e.y.cooling_phase = 1
e.y.barrierFlag = True
e.y.t = 0;
e.y.g22 = 0.75 * e.y.g11
e.y.g12 = 0
e.y.barrierOffset = -3.5
e.y.barrierIensity = 10.0
e.y.barrierWidth = np.array([0.3,])
e.y.barrierVelocity = np.array([.175,])
with NoInterrupt(ignore=True) as interrupted:
    while e.y.t < 2*u.ms and not interrupted:
        e.evolve(100)
        plt.clf()
        e.y.plot()
        plt.plot(e.y.xyz[0],e.y.get_V()[0])
        display(plt.gcf())
        clear_output(wait=True)
# Out:
# AssertionErrorTraceback (most recent call last)
# <ipython-input-30-4f0bd88ea2aa> in <module>()
#      11 with NoInterrupt(ignore=True) as interrupted:
#      12     while e.y.t < 2*u.ms and not interrupted:
# ---> 13         e.evolve(100)
#      14         plt.clf()
#      15         e.y.plot()
#
# /projects/990b1d3c-5a22-40a3-849e-cd68d8e43eb4/.local/lib/python2.7/site-packages/pytimeode/evolvers.pyc in evolve(self, steps, omega)
#     116
#     117         for kt in xrange(1, steps-1):
# --> 118             self.do_step()
#     119
#     120         self.do_step(final=True)
#
# /projects/990b1d3c-5a22-40a3-849e-cd68d8e43eb4/.local/lib/python2.7/site-packages/pytimeode/evolvers.pyc in do_step(self, first, final)
#     344         else:
#     345             # self.do_step_ABM()
# --> 346             self.do_step_ABM_numexpr()
#     347
#     348     def do_step_runge_kutta(self):
#
# /projects/990b1d3c-5a22-40a3-849e-cd68d8e43eb4/.local/lib/python2.7/site-packages/pytimeode/evolvers.pyc in do_step_ABM_numexpr(self)
#     486         # Compute dm = m' in the _tmp array
#     487         dm = self._tmp
# --> 488         dm = self.get_dy(y=m, t=t+dt, dy=dm)
#     489
#     490         # Computed dcp
#
# /projects/990b1d3c-5a22-40a3-849e-cd68d8e43eb4/.local/lib/python2.7/site-packages/pytimeode/evolvers.pyc in get_dy(self, y, t, dy)
#     100
#     101         with y.lock:
# --> 102             dy = y.compute_dy_dt(dy=dy)
#     103
#     104         if t0 is not None:
#
# /projects/990b1d3c-5a22-40a3-849e-cd68d8e43eb4/Chunde/SOC-BEC/CoupledState2.pyc in compute_dy_dt(self, dy, subtract_mu)
#     197         if subtract_mu:
#     198             mu = self.braket(y, Hy)/self.braket(y, y) # the energy expectation
# --> 199             assert np.allclose(0, mu.imag)
#     200             Hy[...] -= mu*y
#     201             self._mu = mu
#
# AssertionError:
